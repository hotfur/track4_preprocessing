# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1JaKi-Kp2uXJhD18ui3A3AHODFO-ePmPT' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1JaKi-Kp2uXJhD18ui3A3AHODFO-ePmPT" -O modelTrained.zip && rm -rf /tmp/cookies.txt
# !unzip modelTrained.zip -d /content
# Out:
# --2022-05-11 07:02:49--  https://docs.google.com/uc?export=download&confirm=t&id=1JaKi-Kp2uXJhD18ui3A3AHODFO-ePmPT
# Resolving docs.google.com (docs.google.com)... 74.125.195.113, 74.125.195.102, 74.125.195.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.195.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-10-6g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/pjqmfe9isijs09p41rv7mjov9ggg283e/1652252550000/10805074971723296642/*/1JaKi-Kp2uXJhD18ui3A3AHODFO-ePmPT?e=download [following]
# ...
# --2022-05-11 07:02:49--  https://doc-10-6g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/pjqmfe9isijs09p41rv7mjov9ggg283e/1652252550000/10805074971723296642/*/1JaKi-Kp2uXJhD18ui3A3AHODFO-ePmPT?e=download
# Resolving doc-10-6g-docs.googleusercontent.com (doc-10-6g-docs.googleusercontent.com)... 74.125.20.132, 2607:f8b0:400e:c07::84
# ...

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1q51L-nBpaGtxjIOII_QTiDc6IzUm0951' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1q51L-nBpaGtxjIOII_QTiDc6IzUm0951" -O code.zip && rm -rf /tmp/cookies.txt
# !unzip code.zip -d /content
# Out:
# --2022-05-11 07:05:49--  https://docs.google.com/uc?export=download&confirm=&id=1q51L-nBpaGtxjIOII_QTiDc6IzUm0951
# Resolving docs.google.com (docs.google.com)... 173.194.203.139, 173.194.203.138, 173.194.203.102, ...
# Connecting to docs.google.com (docs.google.com)|173.194.203.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-6g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/u2npp0kjqvmdk1mkdvnjo4oqff2jedhc/1652252700000/10805074971723296642/*/1q51L-nBpaGtxjIOII_QTiDc6IzUm0951?e=download [following]
# ...
# --2022-05-11 07:05:50--  https://doc-08-6g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/u2npp0kjqvmdk1mkdvnjo4oqff2jedhc/1652252700000/10805074971723296642/*/1q51L-nBpaGtxjIOII_QTiDc6IzUm0951?e=download
# Resolving doc-08-6g-docs.googleusercontent.com (doc-08-6g-docs.googleusercontent.com)... 74.125.20.132, 2607:f8b0:400e:c07::84
# ...

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1a3BK_zMhuQAYkoZ4bb6jjuWxEvsuY9HJ' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1a3BK_zMhuQAYkoZ4bb6jjuWxEvsuY9HJ" -O test.zip && rm -rf /tmp/cookies.txt
# !unzip test.zip -d /content/Videos
# Out:
# --2022-04-17 20:57:04--  https://docs.google.com/uc?export=download&confirm=t&id=1a3BK_zMhuQAYkoZ4bb6jjuWxEvsuY9HJ
# Resolving docs.google.com (docs.google.com)... 108.177.97.101, 108.177.97.139, 108.177.97.138, ...
# Connecting to docs.google.com (docs.google.com)|108.177.97.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-6g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/st9j83pnf2tpvga4hmhsljcmonv4d125/1650228975000/10805074971723296642/*/1a3BK_zMhuQAYkoZ4bb6jjuWxEvsuY9HJ?e=download [following]
# ...
# --2022-04-17 20:57:05--  https://doc-0s-6g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/st9j83pnf2tpvga4hmhsljcmonv4d125/1650228975000/10805074971723296642/*/1a3BK_zMhuQAYkoZ4bb6jjuWxEvsuY9HJ?e=download
# Resolving doc-0s-6g-docs.googleusercontent.com (doc-0s-6g-docs.googleusercontent.com)... 142.250.157.132, 2404:6800:4008:c13::84
# ...

# %%
# !pip install tensorflow_addons
# Out:
# ...
#      |████████████████████████████████| 1.1 MB 4.2 MB/s
# ...

# %%
import os
videos = os.listdir('/content/Videos')
videos.sort()
with open('videos.txt', 'w') as f:
    for video in videos:
      f.write('/content/Videos/' + video + '\n')
    f.close()

# %%
fileVideo = open('/content/videos.txt', "r")
Lines = fileVideo.readlines()
Lines.sort()
videoNames = []
for x in Lines:
  videoNames.append(x.rstrip('\n'))

# %%
# !rm -r Result
# !mkdir Result

# !rm -r frame
# !mkdir frame

# !rm -r Object
# !mkdir Object

# !rm -r ROI
# !mkdir ROI

# !rm -r FG
# !mkdir FG

# !rm -r MVO
# !mkdir MVO

# !rm -r dirSkinMask
# !mkdir dirSkinMask

# !rm -r dirSkinRemoval
# !mkdir dirSkinRemoval

# !rm -r FinalResult
# !mkdir FinalResult

# %%
# !python main.py --videos /content/videos.txt --weight /content/content/Incepresnetv2_4_total
# Out:
# Streaming output truncated to the last 5000 lines.
# FinalResult/testA_3.mp4/1976_8_Object ID_19_Class_116_Prob_0.9983046054840088.jpg
# FPS = 5.364321505354859 at 1976
#
#
# FPS = 5.503440354741352 at 1977
#
#
# FPS = 27.932789565863658 at 1978
#
#
# FPS = 30.53534076344104 at 1979
#
#
# FPS = 30.008613251303952 at 1980
#
#
# FPS = 32.56978127949771 at 1981
#
#
# FPS = 42.84711227179677 at 1982
#
#
# FPS = 27.352431381123285 at 1983
#
#
# FPS = 34.0986452337703 at 1984
#
#
# FPS = 28.896539960999572 at 1985
#
#
# FPS = 47.62736388163694 at 1986
#
#
# FPS = 33.22036687600436 at 1987
#
#
# FPS = 35.987471784893934 at 1988
#
#
# FPS = 26.365340885417424 at 1989
#
#
# FPS = 35.121113450322994 at 1990
#
#
# FPS = 27.614270185315302 at 1991
#
#
# FPS = 43.90883678101599 at 1992
#
#
# FPS = 35.78452222428833 at 1993
#
#
# FPS = 41.37128707735343 at 1994
#
#
# FPS = 34.68373318883552 at 1995
#
#
# FPS = 44.57473020149667 at 1996
#
#
# FPS = 32.69188812670722 at 1997
#
#
# ...

# %%
# !zip -r "/content/Result_track4.zip" "/content/FinalResult"
# Out:
# updating: content/FinalResult/ (stored 0%)
# updating: content/FinalResult/testA_3.mp4/ (stored 0%)
# updating: content/FinalResult/testA_3.mp4/849_4_Object ID_8_Class_46_Prob_0.961299479007721.jpg (deflated 1%)
# updating: content/FinalResult/testA_3.mp4/848_4_Object ID_8_Class_46_Prob_0.9532473087310791.jpg (deflated 1%)
# updating: content/FinalResult/testA_3.mp4/172_1_Object ID_4_Class_21_Prob_0.9823383688926697.jpg (deflated 3%)
# updating: content/FinalResult/testA_3.mp4/361_2_Object ID_6_Class_80_Prob_0.9999998807907104.jpg (deflated 2%)
# updating: content/FinalResult/testA_3.mp4/151_0_Object ID_4_Class_21_Prob_0.9999232292175293.jpg (deflated 2%)
# updating: content/FinalResult/testA_3.mp4/130_2_Object ID_4_Class_21_Prob_0.9916110634803772.jpg (deflated 2%)
# updating: content/FinalResult/testA_3.mp4/378_3_Object ID_6_Class_80_Prob_0.9999998807907104.jpg (deflated 2%)
# ...
